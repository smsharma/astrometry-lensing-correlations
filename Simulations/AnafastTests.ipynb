# %%
import numpy as np
import healpy as hp
import matplotlib.pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from NPTFit import create_mask as cm

# %%
nside = 512
plt.plot(hp.anafast(~cm.make_mask_total(nside, mask_ring=True, outer = 5, ring_b=0, ring_l=0)))
plt.plot(hp.anafast(~cm.make_mask_total(nside, mask_ring=True, outer = 5, ring_b=90, ring_l=80)))

# plt.xscale("log")
plt.yscale("log")
